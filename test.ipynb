# %%
# %matplotlib inline

# %% [markdown]
# ### test

# %%
import datetime

class AddressBook:

 person_list = []

#新規にアドレス帳に人を追加する。
 def add(self,person):
    self.person_list.append(person)

#登録された個人一覧を表示する。
 def show_all(self):
    for person in self.person_list:
        print(person.lastname+' '+person.firstname)

#検索条件にマッチする人を表示する。
 def search(self,keyword):
    for person in self.person_list:
     if keyword in person.firstname or keyword in person.lastname:
         print (person.firstname+''+person.lastname)

class Person:
    firstname=''
    lastname=''
    tel=''
    mail_address=''
    birthday=datetime.datetime(2000,1,1)

ab=AddressBook()

p=Person()
p.firstname='はるみ'
p.lastname='いとう'
p.tel='08067431055'

ab.add(p)

p2=Person()
p2.firstname='Ito'
p2.lastname='Harumi'
p2.tel='0456621075'

print('動作確認')
ab.add(p2)

print('アドレス帳の人数->'+str(len(ab.person_list))+'人')

print('一覧表示')
ab.show_all()

print('検索')
ab.search('Harumi')
# Out:
# 動作確認
# アドレス帳の人数->2人
# 一覧表示
# いとう はるみ
# Harumi Ito
# 検索
# ItoHarumi

# %%
a=1
print(a)
# Out:
# 1

# %%
#import matplotlib.font_manager
#print([f.name for f in matplotlib.font_manager.fontManager.ttflist])

# %% [markdown]
# # 修正内容
# 1_ 2週ごとに入力するグラフ<br>
# 入力する内容はその検診日の体重<br>
# 2_ 横軸を4週刻みに<br>
# 3_ 外部から数値を受け入れられるようにしておく。<br>

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Kozuka Mincho Pr6N'
#matplotlib を使うには、このコードで、matplotlib.pyplot クラスを plt という名前で読み込む。
import seaborn
import numpy as np


# 折れ線グラフを出力
left = np.array([8,41,4.0])#妊娠８週から、４週間刻みで41週まで。
height = np.array([-4,14,2.0])#-4〜+14までを、２キロずつ。
plt.plot(left, height)

plt.title("妊娠週数と体重増加")
plt.xlabel("妊娠週数　(週)")
plt.ylabel("体重増加量　(kg)")
plt.grid(True)

plt.show()


#思っているグラフと違うのだけど。。。
